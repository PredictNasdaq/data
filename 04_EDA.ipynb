# %%
import pandas as pd

# 데이터 불러오기
data = pd.read_csv('data.csv')

# 데이터 확인
data.head()
# Out:
#    status_id         author_name            user_id            post_time  \
# 0       1824     Donald J. Trump   @realDonaldTrump  2022-02-14 10:54:00
# 1       1810  Joshua Hooser 🙏🏻🇺🇸      @joshuahooser  2022-03-04 09:59:00
# 2      22298   Gustav Pettersson  @gustavpettersson  2022-03-14 13:24:00
# 3      22297   Gustav Pettersson  @gustavpettersson  2022-03-14 13:24:00
# 4      22296             🗽🅶🆁🅴🅶ⁿʲ        @Gregpogo35  2022-03-14 15:11:00
#
#                                         post_content
# 0  Get Ready!  Your favorite President will see y...
# 1  Get involved in YOUR government. Last year I r...
# 2  ReTruth if you think THIS is the best comeback...
# 3  ReTruth if you think THIS is the best comeback...
# 4  RETRUTH IF YOU CAN’T STAND THESE 2 IGNORANT PE...

# %%
# Display basic statistics
print(data.describe(include='all'))

# Check for missing values
print(data.isnull().sum())

# Visualize the distribution of 'post_time'
import matplotlib.pyplot as plt

data['post_time'] = pd.to_datetime(data['post_time'])
data['post_time'].dt.date.value_counts().sort_index().plot(kind='line', figsize=(12, 6))
plt.title('Number of Posts Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Posts')
plt.show()

# Visualize the distribution of 'author_name'
data['author_name'].value_counts().head(10).plot(kind='bar', figsize=(12, 6))
plt.title('Top 10 Authors by Number of Posts')
plt.xlabel('Author Name')
plt.ylabel('Number of Posts')
plt.show()
# Out:
#           status_id      author_name           user_id            post_time  \
# count   22879.00000            22879             22879                22879
# unique          NaN              600               601                15803
# top             NaN  Donald J. Trump  @realDonaldTrump  2024-08-13 18:22:00
# freq            NaN            16396             16396                   17
# mean    14442.63897              NaN               NaN                  NaN
# std      8391.76607              NaN               NaN                  NaN
# min         1.00000              NaN               NaN                  NaN
# 25%      7195.50000              NaN               NaN                  NaN
# 50%     14393.00000              NaN               NaN                  NaN
# 75%     21821.50000              NaN               NaN                  NaN
# max     28815.00000              NaN               NaN                  NaN
#
#                         post_content
# count                          22879
# unique                         17449
# top     https://www.DonaldJTrump.com
# freq                             210
# mean                             NaN
# std                              NaN
# min                              NaN
# 25%                              NaN
# 50%                              NaN
# 75%                              NaN
# max                              NaN
# status_id       0
# author_name     0
# user_id         0
# post_time       0
# post_content    0
# dtype: int64
# c:\Users\yunjh\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127482 (\N{REGIONAL INDICATOR SYMBOL LETTER U}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\yunjh\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127480 (\N{REGIONAL INDICATOR SYMBOL LETTER S}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\yunjh\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129413 (\N{EAGLE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
